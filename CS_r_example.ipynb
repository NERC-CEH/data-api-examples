# %% [markdown]
# <a href="https://colab.research.google.com/github/NERC-CEH/data-api-examples/blob/master/CS_r_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Countryside Survey data-api demo

[This r notebook](https://github.com/NERC-CEH/data-api-examples/blob/master/cs-r.Rmd) demonstrates how to get data from the Countryside Survey data-api.

Run it in an r environment of your choice - for example RStudio, or through a browser at [rstudio.cloud](https://rstudio.cloud).

## Find out more about the Countryside Survey api

- Full information about Countryside Survey data: https://catalogue.ceh.ac.uk/documents/2069de82-619d-4751-9904-aec8500d07e6
- Information about Countryside Survey data api and more examples: https://data-eidc.ceh.ac.uk/docs/cs

# %%
## Install dependencies
library(jsonlite) # tools to work with the json data coming back from data-api
library(httr) # http request libray, needed to communicate with the data-api
library(glue) # useful string templating library

# %% [markdown]
# ## Add your authorisation token
# Create a token with [Data Api Auth](https://data-eidc.ceh.ac.uk/authentication) for the following licences: LICENCE_OGL.
#
# You will now have a token that looks something like 30dd8762241695749a32d2910d354695
#
# Enter it when prompted when running this code block:

# %%
token = readline(prompt = 'Enter authorisation token:')
# Out:
# Enter authorisation token:8bd84eb7531fcb18d725393b3bb8990a

# %% [markdown]
# ## Set the base url
#
# This is the url to the Countryside Survey data api.

# %%
url = 'https://data-eidc.ceh.ac.uk/1.0/2069de82-619d-4751-9904-aec8500d07e6'

# %% [markdown]
# ## Setup functions for handling data api requests
#
# These functions are the way requests for data are sent and responses received.
#
# They use r's httr package to do this.

# %%
# The /metadata endpoint
# Metadata is returned in json format
# query: this is an optional object of key-value pairs for refining the query
cs_metadata <- function(query = {}) {
  response = GET(
    url = glue::glue('{url}/metadata'),
    add_headers(Authorization = glue::glue('bearer {token}')),
    query = query
  )
  # Pull out the content from the response and turn into a string, 
  # this will be a string representation of the json data
  return(rawToChar(response$content))
}
# The /metadata/key/{key} endpoint
# Metadata is returned in json format
# key: this is the key that you want metadata for
cs_keyvalues <- function(key) {
  response = GET(
    url = glue::glue('{url}/metadata/key/{key}'),
    add_headers(Authorization = glue::glue('bearer {token}'))
  )
  return(rawToChar(response$content))
}
# The /data endpoint
# Data is returned in csv format
# bodyjson: this is the body of the request that defines what data you want
cs_data <- function(bodyjson) {
  response = POST(
    url=glue::glue('{url}/data'),
    add_headers(Authorization=glue::glue('bearer {token}'),Accept='text/csv','Content-Type'='application/json'),
    body=bodyjson
  )
  return(rawToChar(response$content))
}

# %% [markdown]
# ## Metadata Request
#
# The Countryside Survey Data API has a metadata endpoint (/metadata) that describes csv files available for the different surveys. It can be used to automate your work and include new Countryside Survey data as it becomes available.
#
# The metadata is derived from the [EIDC catalogue entry](https://catalogue.ceh.ac.uk/documents/2069de82-619d-4751-9904-aec8500d07e6)
#
# It can be used to return all metadata, or refined by the use of metadata keys to create a subset of the metadata you need (eg years=2007). The following shows both types of query, the metadata keys are described later.

# %%
# This gets all the metadata for all the Countryside Survey csv files
# The json data is returned as a json string from the previously defined cs_metadata() method.
# prettify() allows a quick view of the data in a nice format.
prettify(cs_metadata())
# This gets just the vegetation survey metadata for the year 2007.
prettify(cs_metadata(list(tags = "veget", years = "2007")))
# Out:
# [
#     {
#         "acronym": "ebha",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT",
#                 "type": "string"
#             },
#             {
#                 "name": "BROAD_HABITAT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "BROAD_HABITAT ",
#                     "BROAD_HABITAT_NAME ",
#                     "LAND_CLASS_AREA",
#                     "MEAN_ESTIMATE",
#                     "LOWER_ESTIMATE",
#                     "UPPER_ESTIMATE"
#                 ],
#                 "filename": "c8feabac-7c3f-4c35-91f7-296782b957d1.csv"
#             }
#         ],
#         "parent": "3083609a-5f6e-4b33-a061-47275787b7e4",
#         "parent_title": "Countryside Survey 1978",
#         "tag": "habitat",
#         "title": "Countryside Survey 1978 estimates of Broad Habitat areas in Great Britain",
#         "uid": "c8feabac-7c3f-4c35-91f7-296782b957d1",
#         "words": "estim broad habitat area",
#         "year": "1978"
#     },
#     {
#         "acronym": "ebha",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "BROAD_HABITAT",
#                     "BROAD_HABITAT_NAME",
#                     "LAND_CLASS_AREA",
#                     "MEAN_ESTIMATE",
#                     "LOWER_ESTIMATE",
#                     "UPPER_ESTIMATE"
#                 ],
#                 "filename": "CS1984_Broad_Habitat_Stock.csv"
#             }
#         ],
#         "parent": "16965a9e-3e04-4037-ba06-aea211567d44",
#         "parent_title": "Countryside Survey 1984",
#         "tag": "habitat",
#         "title": "Countryside Survey 1984 estimates of Broad Habitat areas in Great Britain",
#         "uid": "ad823866-cded-4778-9bd7-999c821b120e",
#         "words": "estim broad habitat area",
#         "year": "1984"
#     },
#     {
#         "acronym": "ebha",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "BROAD_HABITAT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "BROAD_HABITAT ",
#                     "BROAD_HABITAT_NAME ",
#                     "LAND_CLASS_AREA",
#                     "MEAN_ESTIMATE",
#                     "LOWER_ESTIMATE",
#                     "UPPER_ESTIMATE"
#                 ],
#                 "filename": "CS1990_BroadHabitats_Stock.csv"
#             }
#         ],
#         "parent": "a7a05363-4232-4c21-9e52-8bdb1b6d5f0a",
#         "parent_title": "Countryside Survey 1990",
#         "tag": "habitat",
#         "title": "Countryside Survey 1990 estimates of Broad Habitat areas in Great Britain",
#         "uid": "32dda22c-24cc-4fa8-adcb-5481b1b77ef1",
#         "words": "estim broad habitat area",
#         "year": "1990"
#     },
#     {
#         "acronym": "ebha",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "BROAD_HABITAT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "BROAD_HABITAT ",
#                     "BROAD_HABITAT_NAME ",
#                     "LAND_CLASS_AREA",
#                     "MEAN_ESTIMATE",
#                     "LOWER_ESTIMATE",
#                     "UPPER_ESTIMATE"
#                 ],
#                 "filename": "CS1998_Broad_Habitat_Stock.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "habitat",
#         "title": "Countryside Survey 1998 estimates of Broad Habitat areas in Great Britain",
#         "uid": "acbb0f9c-f2a5-4cbd-97c3-84e786f2e479",
#         "words": "estim broad habitat area",
#         "year": "2000"
#     },
#     {
#         "acronym": "ebha",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "BROAD_HABITAT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BROAD_HABITAT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "BROAD_HABITAT ",
#                     "BROAD_HABITAT_NAME ",
#                     "LAND_CLASS_AREA",
#                     "MEAN_ESTIMATE",
#                     "LOWER_ESTIMATE",
#                     "UPPER_ESTIMATE"
#                 ],
#                 "filename": "CS2007_Broad_Habitat_Stock.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "habitat",
#         "title": "Countryside Survey 2007 estimates of Broad Habitat areas in Great Britain",
#         "uid": "f03cba75-8bca-4679-ae2a-77a9fcbd4df3",
#         "words": "estim broad habitat area",
#         "year": "2007"
#     },
#     {
#         "acronym": "elfl",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURENO",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURE",
#                 "type": "string"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "FEATURENO",
#                     "FEATURE",
#                     "LOWER_ESTIMATE",
#                     "MEAN_ESTIMATE",
#                     "UPPER_ESTIMATE",
#                     "LAND_CLASS_AREA"
#                 ],
#                 "filename": "CS1984_Linear_Stock.csv"
#             }
#         ],
#         "parent": "16965a9e-3e04-4037-ba06-aea211567d44",
#         "parent_title": "Countryside Survey 1984",
#         "tag": "featur",
#         "title": "Countryside Survey 1984 estimates of linear feature lengths in Great Britain",
#         "uid": "271d398c-29de-4ff9-ba68-1b8e0621c6ee",
#         "words": "estim linear featur length",
#         "year": "1984"
#     },
#     {
#         "acronym": "elfl",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURENO",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURE",
#                 "type": "string"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "FEATURENO",
#                     "FEATURE",
#                     "LOWER_ESTIMATE",
#                     "MEAN_ESTIMATE",
#                     "UPPER_ESTIMATE",
#                     "LAND_CLASS_AREA"
#                 ],
#                 "filename": "CS1990_Linear_Stock.csv"
#             }
#         ],
#         "parent": "a7a05363-4232-4c21-9e52-8bdb1b6d5f0a",
#         "parent_title": "Countryside Survey 1990",
#         "tag": "featur",
#         "title": "Countryside Survey 1990 estimates of linear feature lengths in Great Britain",
#         "uid": "ebbd1ba0-4497-4c80-891a-34ef3b8989cd",
#         "words": "estim linear featur length",
#         "year": "1990"
#     },
#     {
#         "acronym": "elfl",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURENO",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURE",
#                 "type": "string"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "FEATURENO",
#                     "FEATURE",
#                     "LOWER_ESTIMATE",
#                     "MEAN_ESTIMATE",
#                     "UPPER_ESTIMATE",
#                     "LAND_CLASS_AREA"
#                 ],
#                 "filename": "CS1998_Linear_Stock.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "featur",
#         "title": "Countryside Survey 1998 estimates of linear feature lengths in Great Britain",
#         "uid": "59422890-c8d3-49b8-b17e-4f5062475140",
#         "words": "estim linear featur length",
#         "year": "2000"
#     },
#     {
#         "acronym": "elfl",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LAND_CLASS",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURENO",
#                 "type": "string"
#             },
#             {
#                 "name": "FEATURE",
#                 "type": "string"
#             },
#             {
#                 "name": "LOWER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MEAN_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "UPPER_ESTIMATE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LAND_CLASS_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "LAND_CLASS",
#                     "FEATURENO",
#                     "FEATURE",
#                     "LOWER_ESTIMATE",
#                     "MEAN_ESTIMATE",
#                     "UPPER_ESTIMATE",
#                     "LAND_CLASS_AREA"
#                 ],
#                 "filename": "CS2007_Linear_Stock.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "featur",
#         "title": "Countryside Survey 2007 estimates of linear feature lengths in Great Britain",
#         "uid": "e687330b-a0f7-45a1-b58c-398e67da3028",
#         "words": "estim linear featur length",
#         "year": "2007"
#     },
#     {
#         "acronym": "fpq",
#         "columns": [
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "Variable",
#                 "type": "string"
#             },
#             {
#                 "name": "Description",
#                 "type": "string"
#             },
#             {
#                 "name": "Code",
#                 "type": "float64"
#             },
#             {
#                 "name": "Percent",
#                 "type": "float64"
#             },
#             {
#                 "name": "Code_desc",
#                 "type": "string"
#             },
#             {
#                 "name": "Rank",
#                 "type": "float64"
#             },
#             {
#                 "name": "TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "AREA",
#                 "type": "string"
#             },
#             {
#                 "name": "SURVEY_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "TOTAL_SUB_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_FL_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_EM_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_WET_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "RARE_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "GT30_PLANT_SP",
#                 "type": "float64"
#             },
#             {
#                 "name": "PSYM_GT75",
#                 "type": "float64"
#             },
#             {
#                 "name": "PSYM_ASSESSMENT",
#                 "type": "string"
#             },
#             {
#                 "name": "BAPPH_07",
#                 "type": "int64"
#             },
#             {
#                 "name": "WATER",
#                 "type": "string"
#             },
#             {
#                 "name": "COND_SURVEY",
#                 "type": "string"
#             },
#             {
#                 "name": "OPEN_PA",
#                 "type": "float64"
#             },
#             {
#                 "name": "VIEW_PROW",
#                 "type": "float64"
#             },
#             {
#                 "name": "COUNTY",
#                 "type": "string"
#             },
#             {
#                 "name": "SPECIES",
#                 "type": "string"
#             },
#             {
#                 "name": "PLANT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "POND_AREA",
#                 "type": "float64"
#             },
#             {
#                 "name": "DRAWDOWN_HEIGHT",
#                 "type": "float64"
#             },
#             {
#                 "name": "PROPORTION_WATER_LEFT_IN_POND",
#                 "type": "float64"
#             },
#             {
#                 "name": "DRIED_OUT",
#                 "type": "float64"
#             },
#             {
#                 "name": "PH",
#                 "type": "float64"
#             },
#             {
#                 "name": "CONDUCTIVITY",
#                 "type": "float64"
#             },
#             {
#                 "name": "ALKALINITY",
#                 "type": "float64"
#             },
#             {
#                 "name": "TURBIDITY",
#                 "type": "float64"
#             },
#             {
#                 "name": "PO4_P",
#                 "type": "float64"
#             },
#             {
#                 "name": "TON",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "SQUARE",
#                     "Variable",
#                     "Description",
#                     "Code",
#                     "Percent",
#                     "Code_desc",
#                     "Rank",
#                     "TYPE",
#                     "YEAR",
#                     "LC07",
#                     "LC07_NUM",
#                     "ENV_ZONE_2007",
#                     "COUNTRY"
#                 ],
#                 "filename": "POND_ENV_SURVEY.csv"
#             },
#             {
#                 "columns": [
#                     "SQUARE",
#                     "YEAR",
#                     "AREA",
#                     "SURVEY_DATE",
#                     "TOTAL_SUB_SP",
#                     "TOTAL_FL_SP",
#                     "TOTAL_EM_SP",
#                     "TOTAL_WET_SP",
#                     "RARE_SP",
#                     "GT30_PLANT_SP",
#                     "PSYM_GT75",
#                     "PSYM_ASSESSMENT",
#                     "BAPPH_07",
#                     "WATER",
#                     "COND_SURVEY",
#                     "OPEN_PA",
#                     "VIEW_PROW",
#                     "LC07",
#                     "LC07_NUM",
#                     "ENV_ZONE_2007",
#                     "COUNTRY",
#                     "COUNTY"
#                 ],
#                 "filename": "POND_SITE_INFO_V_0_1.csv"
#             },
#             {
#                 "columns": [
#                     "SQUARE",
#                     "YEAR",
#                     "SPECIES",
#                     "PLANT_TYPE",
#                     "COVER",
#                     "LC07",
#                     "LC07_NUM",
#                     "ENV_ZONE_2007",
#                     "COUNTRY"
#                 ],
#                 "filename": "POND_MACROPHYTES.csv"
#             },
#             {
#                 "columns": [
#                     "SQUARE",
#                     "YEAR",
#                     "POND_AREA",
#                     "DRAWDOWN_HEIGHT",
#                     "PROPORTION_WATER_LEFT_IN_POND",
#                     "DRIED_OUT",
#                     "PH",
#                     "CONDUCTIVITY",
#                     "ALKALINITY",
#                     "TURBIDITY",
#                     "PO4_P",
#                     "TON",
#                     "LC07",
#                     "LC07_NUM",
#                     "ENV_ZONE_2007",
#                     "COUNTRY"
#                 ],
#                 "filename": "POND_WATER_QUALITY.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "wat",
#         "title": "Freshwater pond quality data 2007 [Countryside Survey] v1.1",
#         "uid": "cbb9ee99-8078-4dc4-87de-ee99390e579e",
#         "words": "freshwat pond qualiti",
#         "year": "2007"
#     },
#     {
#         "acronym": "hsi",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLE_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "SPECIES_CODE",
#                 "type": "string"
#             },
#             {
#                 "name": "NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "WATER_WIDTH",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH1",
#                 "type": "int64"
#             },
#             {
#                 "name": "DEPTH2",
#                 "type": "int64"
#             },
#             {
#                 "name": "DEPTH3",
#                 "type": "int64"
#             },
#             {
#                 "name": "SURF_VEL_CAT",
#                 "type": "int64"
#             },
#             {
#                 "name": "CLARITY",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLING_TIME",
#                 "type": "int64"
#             },
#             {
#                 "name": "METHOD",
#                 "type": "int64"
#             },
#             {
#                 "name": "ROCK_PAVEMT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BOULDER_COBBLE",
#                 "type": "int64"
#             },
#             {
#                 "name": "PEBBLE_GRAVEL",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAND",
#                 "type": "int64"
#             },
#             {
#                 "name": "SILT_CLAY",
#                 "type": "int64"
#             },
#             {
#                 "name": "DOM_PART_SIZE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MACROPHYTE_COVER",
#                 "type": "int64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "SPECIES_CODE",
#                     "NAME",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INVERT_TAXA_90.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "WATER_WIDTH",
#                     "DEPTH1",
#                     "DEPTH2",
#                     "DEPTH3",
#                     "SURF_VEL_CAT",
#                     "CLARITY",
#                     "SAMPLING_TIME",
#                     "METHOD",
#                     "ROCK_PAVEMT",
#                     "BOULDER_COBBLE",
#                     "PEBBLE_GRAVEL",
#                     "SAND",
#                     "SILT_CLAY",
#                     "DOM_PART_SIZE",
#                     "MACROPHYTE_COVER",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INV_SITE_90.csv"
#             }
#         ],
#         "parent": "a7a05363-4232-4c21-9e52-8bdb1b6d5f0a",
#         "parent_title": "Countryside Survey 1990",
#         "tag": "wat",
#         "title": "Headwater stream invertebrate data 1990 [Countryside Survey]",
#         "uid": "b4c17f35-1b50-4ed7-87d2-b63004a96ca2",
#         "words": "headwat stream invertebr",
#         "year": "1990"
#     },
#     {
#         "acronym": "hsi",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLE_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "SPECIES_CODE",
#                 "type": "string"
#             },
#             {
#                 "name": "NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "WATER_WIDTH",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH1",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH2",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH3",
#                 "type": "float64"
#             },
#             {
#                 "name": "SURF_VEL_CAT",
#                 "type": "float64"
#             },
#             {
#                 "name": "ROCK_PAVEMT",
#                 "type": "int64"
#             },
#             {
#                 "name": "BOULDER_COBBLE",
#                 "type": "int64"
#             },
#             {
#                 "name": "PEBBLE_GRAVEL",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAND",
#                 "type": "int64"
#             },
#             {
#                 "name": "SILT_CLAY",
#                 "type": "int64"
#             },
#             {
#                 "name": "DOM_PART_SIZE",
#                 "type": "float64"
#             },
#             {
#                 "name": "MACROPHYTE_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "SPECIES_CODE",
#                     "NAME",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INVERT_TAXA_98.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "WATER_WIDTH",
#                     "DEPTH1",
#                     "DEPTH2",
#                     "DEPTH3",
#                     "SURF_VEL_CAT",
#                     "ROCK_PAVEMT",
#                     "BOULDER_COBBLE",
#                     "PEBBLE_GRAVEL",
#                     "SAND",
#                     "SILT_CLAY",
#                     "DOM_PART_SIZE",
#                     "MACROPHYTE_COVER",
#                     "LC07",
#                     "EZ_DESC_07",
#                     "LC07_NUM",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INV_SITE_98.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "wat",
#         "title": "Headwater stream invertebrate data 1998 [Countryside Survey] ",
#         "uid": "fd0ce233-3b4d-4a5e-abcb-c0a26dd71c95",
#         "words": "headwat stream invertebr",
#         "year": "2000"
#     },
#     {
#         "acronym": "hsi",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLE_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "WATER_WIDTH",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH1",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH2",
#                 "type": "float64"
#             },
#             {
#                 "name": "DEPTH3",
#                 "type": "float64"
#             },
#             {
#                 "name": "SURF_VEL_CAT",
#                 "type": "float64"
#             },
#             {
#                 "name": "SAMPLING_TIME",
#                 "type": "float64"
#             },
#             {
#                 "name": "METHOD",
#                 "type": "float64"
#             },
#             {
#                 "name": "ROCK_PAVEMT",
#                 "type": "float64"
#             },
#             {
#                 "name": "BOULDER_COBBLE",
#                 "type": "float64"
#             },
#             {
#                 "name": "PEBBLE_GRAVEL",
#                 "type": "float64"
#             },
#             {
#                 "name": "SAND",
#                 "type": "float64"
#             },
#             {
#                 "name": "SILT_CLAY",
#                 "type": "float64"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "SPECIES_CODE",
#                 "type": "string"
#             },
#             {
#                 "name": "NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "ABUNDANCE",
#                 "type": "int64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE  ",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "WATER_WIDTH",
#                     "DEPTH1",
#                     "DEPTH2",
#                     "DEPTH3",
#                     "SURF_VEL_CAT",
#                     "SAMPLING_TIME",
#                     "METHOD",
#                     "ROCK_PAVEMT",
#                     "BOULDER_COBBLE",
#                     "PEBBLE_GRAVEL",
#                     "SAND",
#                     "SILT_CLAY",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INV_SITE_07.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "SPECIES_CODE",
#                     "NAME",
#                     "ABUNDANCE",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTRY",
#                     "COUNTY07"
#                 ],
#                 "filename": "STREAM_INVERT_TAXA_07.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "wat",
#         "title": "Headwater stream invertebrate data 2007 [Countryside Survey] ",
#         "uid": "18849325-358b-4af1-b20d-d750b1c723a3",
#         "words": "headwat stream invertebr",
#         "year": "2007"
#     },
#     {
#         "acronym": "hsm",
#         "columns": [
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SURVEY_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLANT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "PROPORTION",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "SQUARE",
#                     "YEAR",
#                     "SITE_ID",
#                     "SURVEY_DATE",
#                     "PLANT_NAME",
#                     "PROPORTION",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTY07",
#                     "COUNTRY"
#                 ],
#                 "filename": "STREAM_MACROPHYTES_98.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "wat",
#         "title": "Headwater stream macrophyte data 1998 [Countryside Survey]",
#         "uid": "e0b638d5-8271-4442-97ef-cf46ea220f5d",
#         "words": "headwat stream macrophyt",
#         "year": "2000"
#     },
#     {
#         "acronym": "hsm",
#         "columns": [
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SURVEY_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLANT_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "PROPORTION",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "SQUARE",
#                     "YEAR",
#                     "SITE_ID",
#                     "SURVEY_DATE",
#                     "PLANT_NAME",
#                     "PROPORTION",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTY07",
#                     "COUNTRY"
#                 ],
#                 "filename": "STREAM_MACROPHYTES_07.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "wat",
#         "title": "Headwater stream macrophyte data 2007 [Countryside Survey]",
#         "uid": "249a90ec-238b-4038-a706-6633c3690d20",
#         "words": "headwat stream macrophyt",
#         "year": "2007"
#     },
#     {
#         "acronym": "hswc",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLE_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "DETERMINAND_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "DETERMINAND_UNITS",
#                 "type": "string"
#             },
#             {
#                 "name": "VALUE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE",
#                     "SITE_ID",
#                     "SAMPLE_DATE",
#                     "DETERMINAND_NAME",
#                     "DETERMINAND_UNITS",
#                     "VALUE",
#                     "LC07",
#                     "LC07_NUM",
#                     "EZ_DESC_07",
#                     "COUNTY07",
#                     "COUNTRY"
#                 ],
#                 "filename": "STREAM_CHEMISTRY_1998.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "wat",
#         "title": "Headwater stream water chemistry data 1998 [Countryside Survey] ",
#         "uid": "b8052165-c6c5-427e-a90c-c536ff46aec8",
#         "words": "headwat stream water chemistri",
#         "year": "2000"
#     },
#     {
#         "acronym": "hswc",
#         "columns": [
#             {
#                 "name": "CS_SURVEY",
#                 "type": "string"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "SITE_ID",
#                 "type": "int64"
#             },
#             {
#                 "name": "SAMPLE_DATE",
#                 "type": "string"
#             },
#             {
#                 "name": "DETERMINAND_NAME",
#                 "type": "string"
#             },
#             {
#                 "name": "DETERMINAND_UNITS",
#                 "type": "string"
#             },
#             {
#                 "name": "VALUE",
#                 "type": "float64"
#             },
#             {
#                 "name": "LC07",
#                 "type": "string"
#             },
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
# ...
#             {
#                 "name": "LC07_NUM",
#                 "type": "int64"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTY07",
#                 "type": "string"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "SQUARE",
#                     "PLOT",
#                     "YEAR",
#                     "NE_NMINTOT",
#                     "MIN_N_STOCK",
#                     "NE_NO3N_PROP_NMIN",
#                     "LC07",
#                     "LC07_NUM",
#                     "COUNTRY",
#                     "COUNTY07",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "CS2007_SOIL_MIN_N.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "soil",
#         "title": "Topsoil mineralisable nitrogen (mineral-N) data 2007 [Countryside Survey]",
#         "uid": "3bafb72b-9f2a-4cbc-a7b8-46e3731c6759",
#         "words": "topsoil mineralis nitrogen mineral-n",
#         "year": "2007"
#     },
#     {
#         "acronym": "vp",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "AMALG_PTYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "BRC_NUMBER",
#                 "type": "float64"
#             },
#             {
#                 "name": "BRC_NAMES",
#                 "type": "string"
#             },
#             {
#                 "name": "TOTAL_COVER",
#                 "type": "int64"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "COUNTRY",
#                     "ENV_ZONE_2007",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "Vegetation Plot - Plot Information 1978.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "AMALG_PTYPE",
#                     "BRC_NUMBER",
#                     "BRC_NAMES",
#                     "TOTAL_COVER"
#                 ],
#                 "filename": "Vegetation Plot - Species List 1978.csv"
#             }
#         ],
#         "parent": "3083609a-5f6e-4b33-a061-47275787b7e4",
#         "parent_title": "Countryside Survey 1978",
#         "tag": "veget",
#         "title": "Countryside Survey 1978 vegetation plot data",
#         "uid": "67bbfabb-d981-4ced-b7e7-225205de9c96",
#         "words": "veget plot",
#         "year": "1978"
#     },
#     {
#         "acronym": "vp",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT",
#                 "type": "string"
#             },
#             {
#                 "name": "AMALG_PTYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "BRC_NUMBER",
#                 "type": "float64"
#             },
#             {
#                 "name": "BRC_NAMES",
#                 "type": "string"
#             },
#             {
#                 "name": "NEST_LEVEL",
#                 "type": "int64"
#             },
#             {
#                 "name": "FIRST_COVER",
#                 "type": "int64"
#             },
#             {
#                 "name": "TOTAL_COVER",
#                 "type": "int64"
#             },
#             {
#                 "name": "PLOT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "AMALG_PTYPE",
#                     "BRC_NUMBER",
#                     "BRC_NAMES",
#                     "NEST_LEVEL",
#                     "FIRST_COVER",
#                     "TOTAL_COVER"
#                 ],
#                 "filename": "Vegetation Plot - Species List 1990.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "COUNTRY",
#                     "ENV_ZONE_2007",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "Vegetation Plot - Plot Information 1990.csv"
#             }
#         ],
#         "parent": "a7a05363-4232-4c21-9e52-8bdb1b6d5f0a",
#         "parent_title": "Countryside Survey 1990",
#         "tag": "veget",
#         "title": "Countryside Survey 1990 vegetation plot data",
#         "uid": "26e79792-5ffc-4116-9ac7-72193dd7f191",
#         "words": "veget plot",
#         "year": "1990"
#     },
#     {
#         "acronym": "vp",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "BRC_NUMBER",
#                 "type": "float64"
#             },
#             {
#                 "name": "BRC_NAMES",
#                 "type": "string"
#             },
#             {
#                 "name": "NEST_LEVEL",
#                 "type": "float64"
#             },
#             {
#                 "name": "FIRST_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "BRC_NUMBER",
#                     "BRC_NAMES",
#                     "NEST_LEVEL",
#                     "FIRST_COVER",
#                     "TOTAL_COVER"
#                 ],
#                 "filename": "Vegetation Plot - Species List 1998.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "COUNTRY",
#                     "ENV_ZONE_2007",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "Vegetation Plot - Plot Information 1998.csv"
#             }
#         ],
#         "parent": "b535ca33-c5e3-48fa-9912-ee9c0502ba1b",
#         "parent_title": "Countryside Survey 2000",
#         "tag": "veget",
#         "title": "Countryside Survey 1998 vegetation plot data",
#         "uid": "07896bb2-7078-468c-b56d-fb8b41d47065",
#         "words": "veget plot",
#         "year": "2000"
#     },
#     {
#         "acronym": "vp",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT",
#                 "type": "string"
#             },
#             {
#                 "name": "AMALG_PTYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "BRC_NUMBER",
#                 "type": "float64"
#             },
#             {
#                 "name": "BRC_NAMES",
#                 "type": "string"
#             },
#             {
#                 "name": "NEST_LEVEL",
#                 "type": "float64"
#             },
#             {
#                 "name": "ZERO_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "FIRST_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "PLOT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "AMALG_PTYPE",
#                     "BRC_NUMBER",
#                     "BRC_NAMES",
#                     "NEST_LEVEL",
#                     "ZERO_COVER",
#                     "FIRST_COVER",
#                     "TOTAL_COVER"
#                 ],
#                 "filename": "Vegetation Plot - Species List 2007.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "COUNTRY",
#                     "ENV_ZONE_2007",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "Vegetation Plot - Plot Information 2007.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "veget",
#         "title": "Countryside Survey 2007 vegetation plot data",
#         "uid": "57f97915-8ff1-473b-8c77-2564cbd747bc",
#         "words": "veget plot",
#         "year": "2007"
#     }
# ]
# [
#     {
#         "acronym": "vp",
#         "columns": [
#             {
#                 "name": "YEAR",
#                 "type": "int64"
#             },
#             {
#                 "name": "SQUARE",
#                 "type": "string"
#             },
#             {
#                 "name": "PLOT",
#                 "type": "string"
#             },
#             {
#                 "name": "AMALG_PTYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "BRC_NUMBER",
#                 "type": "float64"
#             },
#             {
#                 "name": "BRC_NAMES",
#                 "type": "string"
#             },
#             {
#                 "name": "NEST_LEVEL",
#                 "type": "float64"
#             },
#             {
#                 "name": "ZERO_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "FIRST_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "TOTAL_COVER",
#                 "type": "float64"
#             },
#             {
#                 "name": "PLOT_TYPE",
#                 "type": "string"
#             },
#             {
#                 "name": "COUNTRY",
#                 "type": "string"
#             },
#             {
#                 "name": "ENV_ZONE_2007",
#                 "type": "int64"
#             },
#             {
#                 "name": "EZ_DESC_07",
#                 "type": "string"
#             },
#             {
#                 "name": "WORDS",
#                 "type": "string"
#             },
#             {
#                 "name": "TAG",
#                 "type": "string"
#             },
#             {
#                 "name": "UID",
#                 "type": "string"
#             },
#             {
#                 "name": "PARENT",
#                 "type": "string"
#             }
#         ],
#         "files": [
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "AMALG_PTYPE",
#                     "BRC_NUMBER",
#                     "BRC_NAMES",
#                     "NEST_LEVEL",
#                     "ZERO_COVER",
#                     "FIRST_COVER",
#                     "TOTAL_COVER"
#                 ],
#                 "filename": "Vegetation Plot - Species List 2007.csv"
#             },
#             {
#                 "columns": [
#                     "YEAR",
#                     "SQUARE_ID",
#                     "PLOT_ID",
#                     "PLOT_TYPE",
#                     "COUNTRY",
#                     "ENV_ZONE_2007",
#                     "EZ_DESC_07"
#                 ],
#                 "filename": "Vegetation Plot - Plot Information 2007.csv"
#             }
#         ],
#         "parent": "28eb9005-7154-4207-b086-e3bdcd61de4a",
#         "parent_title": "Countryside Survey 2007",
#         "tag": "veget",
#         "title": "Countryside Survey 2007 vegetation plot data",
#         "uid": "57f97915-8ff1-473b-8c77-2564cbd747bc",
#         "words": "veget plot",
#         "year": "2007"
#     }
# ]

# %% [markdown]
# ## Metadata key request
#
# Here is a breakdown of the metadata keys you saw when running the code in the previous example.  They allow the metadata request to be filtered to refine what is returned (eg years=2007).
#
# key | description
#  ---|---
# `acronym` | Shorthand for datasets
# `columns` | All the columns in the dataset, quicker than getting the data and interogating it, it also describe the format of each column
# `files` | Each dataset has different files, if you want to know where the data originally came from. This also describes the columes of the data
# `parent` | Each dataset is part of a parent dataset which you can go search for in the EIDC catalogue
# `parent_title` | The title of the parent dataset
# `tag` | A common tag for datasets which share similar data, this value is derived from the Catalogue
# `title` | The title of the dataset in the catalogue
# `uid` | The id of the dataset which you can use to find in the catalogue
# `words` | Keywords from the title which may be useful for understanding the dataset without having to read all the metadata (alone)
# `year` | The year the dataset was taken
#
# To see what values are available for each key, use the metadata key endpoint (/metadata/key/{key}) as shown in the examples below.

# %%
#Using the function defined earlier, get all the years in the data.
prettify(cs_keyvalues('year'))
#Using the function defined earlier, get all the tags in the data.
prettify(cs_keyvalues('tag'))
# Out:
# [
#     "1978",
#     "1984",
#     "1990",
#     "2000",
#     "2007"
# ]
# [
#     "featur",
#     "habitat",
#     "landscap",
#     "mite",
#     "river",
#     "soil",
#     "veget",
#     "wat"
# ]

# %% [markdown]
# ## Data endpoint
#
# The data endpoint (/data) is where you can get the data in CSV format. It automatically combines common data together and will attempt to merge datasets together using an outer join on common column names.
#
# A simple example follows, however more complex examples of data querying written in Python can be found in [these github examples](https://github.com/NERC-CEH/data-api-examples/blob/master/cs-python3-cs.ipynb)
#
# ### Example
#
# This example pulls out some data and prints some values.
#
# Pull out data for 'linear and point features' for 2007.  Just get the columns: SQUARE, LAND_CLASS, FEATURE, MEAN_ESTIMATE

# %%
# Setup the json filter that needs passing into the request
json_body <- jsonlite::toJSON(
  list(
    metadata = list(
      tags=list('featur'), 
      years=list('2007'),
      colums=list('SQUARE','LAND_CLASS','FEATURE','MEAN_ESTIMATE')
    )
  ), auto_unbox = TRUE
)
# Get the CS data using the cs_data() method previously defined and pass it into a data frame
df <- read.table(text = cs_data(json_body), sep =",", header = TRUE, stringsAsFactors = FALSE)
# Have a look at some of the data
unique(df[,"SQUARE", drop=FALSE])
unique(df[,"FEATURE", drop=FALSE])
mean(df[,"MEAN_ESTIMATE"], na.rm = TRUE)
# Out:
#        SQUARE
# 1
# 316    XDEYXT
# 434    YDSEWL
# 860    YDGWZL
# 1001   EYAJMO
# 1327   PVFUKI
# 2099   USETNA
# 2273   NPPRGB
# 2538   RXBGEW
# 2712   UAFKOG
# 2995   FMQFWX
# 3013   KKWKFZ
# 3170   PSVKQN
# 3175   ZWKRMA
# 3214   UHWAME
# 3354   NVVBQQ
# 3391   ZNFZXA
# 3403   KMOUQH
# 3880   MZKVCB
# 4543   WFCADS
# 4954   ABOBUL
# 4978   ZMRGTC
# 5285   KRLBBY
# 5537   QERSLS
# 5569   NJXLXX
# 5602   WOSSFN
# 5652   FMAYXW
# 5668   MJNWTN
# 5806   YTTNGG
# 7081   HNKUSP
# ⋮      ⋮
# 107527 YVEKKQ
# 107602 WKTPKP
# 107664 HAWCOO
# 107675 XXFYMD
# 107764 CHTONI
# 107816 HPLWER
# 107991 FALEKI
# 108176 BJUBLC
# 108268 ANHJGW
# 108275 JBQWJT
# 108307 FPZGGG
# 108691 OCGNAL
# 108833 CDHIYE
# 108843 UBXRLL
# 108848 QASSZL
# 108857 BRKIBT
# 109716 DETEQU
# 110352 MFKQWC
# 111585 BQZPSZ
# 111812 VCQDRX
# 112096 GNJLSG
# 112433 WJHOZP
# 112605 YBYWHW
# 112989 ZUKDMR
# 113222 HWJNVP
# 113810 KSIMHY
# 114142 XKNMNN
# 114187 KUWSSI
# 114189 SUADBS
# 114592 CRWYWA
#     FEATURE
# 1   Total
# 2   Hedges
# 3   Wall
# 4   Line of Trees + Fence
# 5   Line of Trees
# 6   Bank/Grass Strip
# 7   Fence
# 316
# [1] 10.15498
